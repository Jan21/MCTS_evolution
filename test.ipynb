# %%
from GridEnv import GridEnv

grid_env, state = GridEnv.from_env(0)

# %%
subgoals = grid_env.propose_subgoal_states(state, support_robot=None)

# %%
grid_env.visualize(state, subgoals)        # board + subgoal list

# %%
subgoals
# Out:
# [(Subgoal(bottleneck=Robot_at(position=(10, 1), color='Red'), support=Robot_at(position=(10, 0), color='Blue'), goal_pos=(10, 2), target_robot=Robot_at(position=(4, 9), color='Red'), helper=Robot_at(position=(12, 8), color='Blue')),
#   8),
#  (Subgoal(bottleneck=Robot_at(position=(10, 1), color='Red'), support=Robot_at(position=(10, 0), color='Green'), goal_pos=(10, 2), target_robot=Robot_at(position=(4, 9), color='Red'), helper=Robot_at(position=(12, 1), color='Green')),
#   16),
#  (Subgoal(bottleneck=Robot_at(position=(10, 1), color='Red'), support=Robot_at(position=(10, 0), color='Yellow'), goal_pos=(10, 2), target_robot=Robot_at(position=(4, 9), color='Red'), helper=Robot_at(position=(13, 14), color='Yellow')),
#   10),
#  (Subgoal(bottleneck=Robot_at(position=(14, 2), color='Red'), support=Robot_at(position=(15, 2), color='Blue'), goal_pos=(10, 2), target_robot=Robot_at(position=(4, 9), color='Red'), helper=Robot_at(position=(12, 8), color='Blue')),
#   6),
# ...
